# %%
import pandas as pd
import csv
rows=[]
with open('../snacks_pieces.csv','r') as f:
    rd=csv.reader(f)
    for row in rd:
        rows.append(row)
rows
# Out:
# [['Date',
#   'Day',
#   'Item',
#   'Measurement',
#   'Ordered',
#   'Wasted',
#   'Amount Brought',
#   'Month'],
#  ['2/11/2017',
#   'Thursday',
#   'samosa ',
#   'pieces',
#   '2900',
#   '366',
#   '2900',
#   'November'],
#  ['2/11/2017',
#   'Thursday',
#   'dahi vada',
#   'pieces',
#   '1800',
#   '76',
#   '1800',
#   'November'],
#  ['3/11/2017',
#   'Friday',
#   'bonda soup ',
#   'pieces',
#   '1800',
#   '447',
#   '1800',
#   'November'],
#  ['3/11/2017',
#   'Friday',
#   'pulav ',
#   'serving',
#   '1800',
#   '53',
#   '1800',
#   'November'],
#  ['6/11/2017',
#   'Monday',
#   'veg cutlet',
#   'pieces',
#   '1800',
#   '0',
#   '1800',
#   'November'],
#  ['6/11/2017',
#   'Monday',
#   'pongal ',
#   'serving',
#   '1800',
#   '0',
#   '1800',
#   'November'],
#  ['7/11/2017', 'Tuesday', 'idly', 'pieces', '1800', '147', '1800', 'November'],
#  ['7/11/2017', 'Tuesday', 'vada', 'pieces', '1800', '0', '1800', 'November'],
#  ['8/11/2017',
#   'Wednesday',
# ...

# %%
snacks=pd.DataFrame(rows, columns=rows[0])
snacks
# Out:
#            Date        Day              Item  Measurement  Ordered  Wasted  \
# 0          Date        Day              Item  Measurement  Ordered  Wasted
# 1     2/11/2017   Thursday           samosa        pieces     2900     366
# 2     2/11/2017   Thursday         dahi vada       pieces     1800      76
# 3     3/11/2017     Friday       bonda soup        pieces     1800     447
# 4     3/11/2017     Friday            pulav       serving     1800      53
# 5     6/11/2017     Monday        veg cutlet       pieces     1800       0
# 6     6/11/2017     Monday           pongal       serving     1800       0
# 7     7/11/2017    Tuesday              idly       pieces     1800     147
# 8     7/11/2017    Tuesday              vada       pieces     1800       0
# 9     8/11/2017  Wednesday       bonda soup        pieces     1900     458
# 10    8/11/2017  Wednesday     shavige bath       serving     1900     335
# ...

# %%
snacks=snacks.drop(0, axis=0)

# %%
import datetime
import calendar
snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,'%d/%m/%Y'))
snacks['Date']=snacks['Date'].apply(lambda x:x-datetime.timedelta(days=365))
snacks['Day']=snacks['Date'].apply(lambda x:x.weekday())
snacks['Day']=snacks['Day'].apply(lambda x:calendar.day_name[x])
snacks
# Out:
#           Date        Day              Item Measurement Ordered Wasted  \
# 1   2016-11-02  Wednesday           samosa       pieces    2900    366
# 2   2016-11-02  Wednesday         dahi vada      pieces    1800     76
# 3   2016-11-03   Thursday       bonda soup       pieces    1800    447
# 4   2016-11-03   Thursday            pulav      serving    1800     53
# 5   2016-11-06     Sunday        veg cutlet      pieces    1800      0
# 6   2016-11-06     Sunday           pongal      serving    1800      0
# 7   2016-11-07     Monday              idly      pieces    1800    147
# 8   2016-11-07     Monday              vada      pieces    1800      0
# 9   2016-11-08    Tuesday       bonda soup       pieces    1900    458
# 10  2016-11-08    Tuesday     shavige bath      serving    1900    335
# 11  2016-11-09  Wednesday           samosa       pieces    2800    239
# 12  2016-11-09  Wednesday         dahi vada      pieces    1700      6
# ...

# %%
item_set=set(snacks['Item'])
print(len(item_set))
print(item_set)
# Out:
# 70
# ...

# %%
"""import random
import string
#''.join(random.choice(string.ascii_uppercase + string.digits, k=N))
random_strings=set()
while len(random_strings)<=70:
    st=''.join(random.sample(string.ascii_lowercase,5))
    random_strings.add(st)
print(random_strings)"""
# Out:
# set(['ngjpd', 'fmzkp', 'iameh', 'zaghp', 'sjqvc', 'rtqdk', 'qnkbh', 'axsvd', 'mngtv', 'jzpfg', 'axmgj', 'gkbzd', 'qcpor', 'arfvq', 'hdieo', 'qlbfn', 'xsfak', 'laoqr', 'veyhd', 'zxfpw', 'phxuc', 'gkxot', 'srogi', 'tocgl', 'fwyxd', 'zdicf', 'alpkm', 'hxkjp', 'umvap', 'tywio', 'ghsqj', 'rethq', 'eyduz', 'rcdkw', 'dktws', 'glysj', 'npilo', 'ajoxk', 'zmrcp', 'tpusa', 'gtmkr', 'fiapm', 'uhrae', 'iynkv', 'qhlit', 'wougz', 'devmk', 'yfobz', 'pnmdu', 'vilsm', 'aiptw', 'fdmzv', 'wgvzc', 'nwmkq', 'iengk', 'tnkpq', 'saxjo', 'lzdqa', 'sorlw', 'ubvhc', 'gfqmt', 'qwcsp', 'euhxj', 'vzmfl', 'aizpb', 'yvrfg', 'gvnmw', 'ubogs', 'jtgrs', 'tpakw', 'gxpmh'])

# %%
"""f=open('../baked_items.txt','r')
lines=f.readlines()
lines_new=[]
for line in lines:
    clist=[]
    for c in line:
        if not (c=='\t' or c=='\n' or c.isdigit() or c=='.'):
            clist.append(c)
    line=''.join(clist)
    line=line.strip()
    lines_new.append(line)
lines_new"""
# Out:
# ['Almond Peach Muffins',
#  'Almond Poppy Seed Muffins',
#  'Apple Allspice Muffins',
#  'Apple Bars',
#  'Apple Bran Muffins',
#  'Apple Bread',
#  'Apple Buttermilk Muffins',
#  'Apple Coffee Cake',
#  'Apple Crunch Muffins',
#  'Apple Date Muffins',
#  'Apple Dumplings',
#  'Apple Fritter Coffee Cake',
#  'Apple Muffins',
#  'Apple Nut Muffins',
#  'Apple Oatmeal Scones',
#  'Apple Scones',
#  'Apple Walnut Sticky Buns',
#  'Applesauce Oatmeal Muffins',
#  'Apple-Sausage Coffeecake',
#  'Apricot Kolaches',
#  'Baba (Polish Coffee Cake)',
#  'Bacon and Potato Scones',
#  'Bacon Breakfast Cookies',
#  'Bacon Chocolate Chip Cookies',
#  'Bacon Cinnamon Rolls',
#  'Bacon Cornflake Cookies',
#  'Bacon Spider Bread',
#  'Baked Blueberry Cake Donuts',
#  'Baked Cinnamon Roll Donuts',
#  'Baked Donuts',
#  'Baked Doughnut Muffins',
#  'Baked Peanut Butter Banana Donuts',
#  'Baked Powdered Donut Holes',
#  'Banana Bars',
#  'Banana Biscuits',
#  'Banana Bread',
# ...

# %%
lines_new.sort(key=len)
print(len(lines_new))
# Out:
# 436

# %%
lines_new=lines_new[0:200]
lines_new.reverse()
print(len(lines_new))
# Out:
# 200

# %%
#lines_new[0]=lines_new[0].split(' ')[1]
#lines_new[1]=lines_new[0]
#lines_new[0]=' '.join([lines_new[0].split(' ')[0],lines_new[0].split(' ')[2]])
#items=[]
#items.append(lines_new.pop(0))
#lines_new.pop(0)
#print(lines_new)
# Out:
# ['Maple Oat Nut Scones', 'French Toast Muffins', 'Finnish Coffee Bread', 'English Muffin Bread', 'Crispy Raisin Scones', 'Cinnamon Coffee Cake', 'Butter Pecan Muffins', 'Bunuelos (Christmas)', "Bonita's Apple Bread", 'Banana Oatmeal Bread', 'Banana Coconut Bread', 'Bacon Cinnamon Rolls', 'Apple Oatmeal Scones', 'Apple Crunch Muffins', 'Almond Peach Muffins', 'Whole Wheat Muffins', 'Texas Cornbread Mix', 'Soft Cinnamon Rolls', 'Shoofly Coffee Cake', 'Pumpkin Pie Muffins', 'Pumpkin Oat Muffins', 'Pecan Peach Muffins', 'Pear Walnut Muffins', 'Orange Peel Muffins', 'Mud Pie Coffee Cake', 'Mocha Pecan Muffins', 'Maple Bacon Muffins', "Jam-in' Good Scones", 'Granola Coffee Cake', 'Froot Loops Muffins', 'Easy Apple Fritters', 'Creole Corn Muffins', 'Coffee Cake Muffins', 'Cinnamon Roll Bites', 'Cinnamon Honey Buns', 'Cinnamon Bun Scones', 'Carrot Cake Muffins', 'Buttermilk Biscuits', 'Blackberry Kolaches', 'Watermelon Muffins', 'Southern Cornbread', 'Rich Cinnamon Buns', 'Raisin Coffee Cake
# ...

# %%
items.add('Salt Biscuit')

# %%
item_list=[]
for item in items:
    c=item[-1]
    if c=='s':
        item=item[:-1]
    item_list.append(item)
item_list
# Out:
# ['Salt Biscuit',
#  'Vegetable Puff',
#  'Chocolate Pastry',
#  'Banana Muffin',
#  'Cinnabun',
#  'Cinnamon Cake',
#  'Koduballe',
#  'Energy Bar',
#  'Brownie',
#  'Plum Cake',
#  'Croissant',
#  'Casserole',
#  'Boondi Mixture',
#  'Granola Bar',
#  'Cornbread',
#  'Carrot Muffin',
#  'Coconut Muffin',
#  'Date Bread',
#  'Chocolate Bread',
#  'Irish Scone',
#  'Chocolate Cookie',
#  'Cherry Scone',
#  'Samosa',
#  'Apple Pastry',
#  'Cream Bun',
#  'Granola Scone',
#  'Bread Roll',
#  'English Muffin',
#  'Coconut Bread',
#  'Chocolate Chip Muffin',
#  'Sugar Cookie',
#  'Sticky Bun',
#  'Apple Bread',
#  'Finnish Coffee Bread',
#  'Spiced Peanut',
#  'Doughnut Muffin',
#  'Key Lime Pie',
#  'Rusk',
#  'Biscuit',
#  'Lemon Scone',
#  'Cream Muffin',
#  'Egg Puff',
#  'Baked Donut',
#  'Apple Pie',
#  'Potato Chip',
#  'Blueberry Cake',
#  'Cheese Cracker',
#  'Lemon Cake',
#  'Pineapple Muffin',
#  'Oatmeal Muffin',
#  'Peach Muffin',
#  'Raisin Roll-Up',
#  'Masala Bun',
# ...

# %%
"""item_list.sort(key=len)
item_list=item_list[:70]
print(item_list)"""

item_list=['Rusk', 'Bagel', 'Samosa', 'Brownie', 'Biscuit', 'Crumpet', 'Popover', 'Kolache', 'Cinnabun', 'Egg Puff', 'Biscotti', 'Koduballe', 'Plum Cake', 'Croissant', 'Casserole', 'Cornbread', 'Cream Bun', 'Apple Pie', 'Apple Bar', 'Energy Bar', 'Date Bread', 'Bread Roll', 'Sticky Bun', 'Lemon Cake', 'Masala Bun', 'Pita Bread', 'Apple Tart', 'Apple Cake', 'Granola Bar', 'Irish Scone', 'Apple Bread', 'Lemon Scone', 'Baked Donut', 'Potato Chip', 'Marble Cake', 'Bran Muffin', 'Irish Bread', 'Nutty Scone', 'Cherry Tart', 'Gingerbread', 'Easter Cake', 'Coffee Cake', 'Salt Biscuit', 'Cherry Scone', 'Apple Pastry', 'Sugar Cookie', 'Key Lime Pie', 'Cream Muffin', 'Peach Muffin', 'Pecan Muffin', 'Caramel Tart', 'Bread Pakoda', 'French Bread', 'Badam Cookie', 'Peach Muffin', 'Maple Muffin', 'Herb Cracker', 'Banana Muffin', 'Cinnamon Cake', 'Carrot Muffin', 'Granola Scone', 'Coconut Bread', 'Spiced Peanut', 'Walnut Muffin', 'Orange Muffin', 'Cinnamon Roll', 'Oatmeal Scone', 'Vegetable Puff', 'Boondi Mixture', 'Coconut Muffin']
print(len(item_list))
# Out:
# 70

# %%
snacks_items=list(snacks['Item'])
print(snacks_items)
# Out:
# ['samosa ', 'dahi vada', 'bonda soup ', 'pulav ', 'veg cutlet', 'pongal ', 'idly', 'vada', 'bonda soup ', 'shavige bath ', 'samosa ', 'dahi vada', 'masala vada', 'pulav ', 'veg cutlet', 'pongal ', 'idly', 'vada', 'bonda soup ', 'veg upma', 'samosa ', 'dahi vada', 'masala vada', 'pulav ', 'maddur vada', 'palak khichdi ', 'aloo bonda', 'veg upma', 'samosa ', 'dahi vada', 'veg cutlet', 'pulav ', 'masala vada', 'pongal ', 'fruit custard', 'veg upma', 'aloo bonda', 'avalakki', 'set dosa ', 'dhokla ', 'vegetable idly ', 'maddur vada', 'missal pav ', 'samosa ', 'dahi vada', 'veg cutlet', 'set dosa', 'banana bajji ', 'vegetable idly', 'bhel puri chat ', 'missal pav ', 'dhokla', 'samosa ', 'veg upma', 'set dosa', 'mangalore buns ', 'rava idly ', 'bhel puri chat ', 'missal pav ', 'veg cutlet', 'samosa ', 'veg upma', 'dahi vada', 'pongal ', 'vegetable idly', 'bhel puri chat ', 'missal pav ', 'dhokla', 'set dosa', 'mangalore bajji ', 'dahi vada', 'veg cutlet', 'samosa ', 'veg upma', 'non grilled
# ...

# %%
item_set=list(item_set)
item_list=list(item_list)
for r in range(len(snacks_items)):
    x=snacks_items[r]
    pos=item_set.index(x)
    snacks_items[r]=item_list[pos]
snacks_items
# Out:
# ['Walnut Muffin',
#  'Samosa',
#  'Brownie',
#  'Salt Biscuit',
#  'Orange Muffin',
#  'Irish Scone',
#  'Spiced Peanut',
#  'Sticky Bun',
#  'Brownie',
#  'Bread Roll',
#  'Walnut Muffin',
#  'Samosa',
#  'Cinnabun',
#  'Salt Biscuit',
#  'Orange Muffin',
#  'Irish Scone',
#  'Spiced Peanut',
#  'Sticky Bun',
#  'Brownie',
#  'Coconut Muffin',
#  'Walnut Muffin',
#  'Samosa',
#  'Cinnabun',
#  'Salt Biscuit',
#  'Cinnamon Roll',
#  'Cherry Scone',
#  'Granola Scone',
#  'Coconut Muffin',
#  'Walnut Muffin',
#  'Samosa',
#  'Orange Muffin',
#  'Salt Biscuit',
#  'Cinnabun',
#  'Irish Scone',
#  'Cornbread',
#  'Coconut Muffin',
#  'Granola Scone',
#  'Cherry Tart',
#  'Maple Muffin',
#  'Marble Cake',
#  'Plum Cake',
#  'Cinnamon Roll',
#  'Apple Cake',
#  'Walnut Muffin',
#  'Samosa',
#  'Orange Muffin',
#  'Apple Tart',
#  'Vegetable Puff',
#  'Biscuit',
#  'Carrot Muffin',
#  'Apple Cake',
#  'Apple Pie',
#  'Walnut Muffin',
#  'Coconut Muffin',
#  'Apple Tart',
# ...

# %%
snacks['Item_New']=snacks_items

# %%
snacks['Item']=snacks['Item_New']
snacks.pop('Item_New')
snacks.pop('Measurement')
snacks.pop('Amount Brought')
# Out:
# 1      2900
# 2      1800
# 3      1800
# 4      1800
# 5      1800
# 6      1800
# 7      1800
# 8      1800
# 9      1900
# 10     1900
# 11     2800
# 12     1700
# 13     1900
# 14     1900
# 15     2300
# 16     1900
# 17     1600
# 18     2500
# 19     1800
# 20     1800
# 21     2600
# 22     1700
# 23     1800
# 24     1800
# 25     1900
# 26     1900
# 27     1900
# 28     1900
# 29     2700
# 30     1800
#        ...
# 287    3863
# 288    1607
# 289    1682
# 290    1454
# 291    1143
# 292     911
# 293    1889
# 294    1867
# 295    1374
# 296    1690
# 297    1687
# 298    1595
# 299    1600
# 300    1700
# 301    1600
# 302    1400
# 303    1700
# 304    1800
# 305    1800
# 306    1800
# 307    1800
# 308    1800
# 309    1500
# 310    1500
# 311    1800
# 312    1800
# 313    3600
# 314    1800
# 315    1300
# 316    1800
# Name: Amount Brought, dtype: object

# %%
#snacks['Ordered']=snacks['Ordered'].apply(lambda x:eval(x)//10)
#snacks['Consumed']=snacks['Ordered'].apply(lambda x:int(0.95*x))
snacks.pop('Wasted')
# Out:
# 1       366
# 2        76
# 3       447
# 4        53
# 5         0
# 6         0
# 7       147
# 8         0
# 9       458
# 10      335
# 11      239
# 12        6
# 13      376
# 14       29
# 15       29
# 16        0
# 17      186
# 18      648
# 19      515
# 20        0
# 21        0
# 22       26
# 23      601
# 24      285
# 25      210
# 26     1020
# 27      160
# 28      224
# 29      403
# 30      620
#        ...
# 287       0
# 288       0
# 289     229
# 290      18
# 291     116
# 292       0
# 293       0
# 294       0
# 295     194
# 296     193
# 297     103
# 298       0
# 299      60
# 300       0
# 301     170
# 302      40
# 303      22
# 304     154
# 305       0
# 306      66
# 307     402
# 308       0
# 309     127
# 310      34
# 311      62
# 312     382
# 313     888
# 314     173
# 315     250
# 316       0
# Name: Wasted, dtype: object

# %%
#snacks.pop('Wasted')
snacks
# Out:
#           Date        Day            Item Ordered     Month
# 1   2016-11-02  Wednesday   Walnut Muffin    2900  November
# 2   2016-11-02  Wednesday          Samosa    1800  November
# 3   2016-11-03   Thursday         Brownie    1800  November
# 4   2016-11-03   Thursday    Salt Biscuit    1800  November
# 5   2016-11-06     Sunday   Orange Muffin    1800  November
# 6   2016-11-06     Sunday     Irish Scone    1800  November
# 7   2016-11-07     Monday   Spiced Peanut    1800  November
# 8   2016-11-07     Monday      Sticky Bun    1800  November
# 9   2016-11-08    Tuesday         Brownie    1900  November
# 10  2016-11-08    Tuesday      Bread Roll    1900  November
# 11  2016-11-09  Wednesday   Walnut Muffin    2800  November
# 12  2016-11-09  Wednesday          Samosa    1700  November
# 13  2016-11-10   Thursday        Cinnabun    1900  November
# 14  2016-11-10   Thursday    Salt Biscuit    1900  November
# 15  2016-11-13     Sunday   Orange Muffin    2300  November
# ...

# %%
snacks['Percentage Consumed']=snacks['Ordered'].apply(lambda x:95)

# %%
#snacks.pop('Consumed')
snacks
# Out:
#           Date        Day            Item Ordered     Month  \
# 1   2016-11-02  Wednesday   Walnut Muffin    2900  November
# 2   2016-11-02  Wednesday          Samosa    1800  November
# 3   2016-11-03   Thursday         Brownie    1800  November
# 4   2016-11-03   Thursday    Salt Biscuit    1800  November
# 5   2016-11-06     Sunday   Orange Muffin    1800  November
# 6   2016-11-06     Sunday     Irish Scone    1800  November
# 7   2016-11-07     Monday   Spiced Peanut    1800  November
# 8   2016-11-07     Monday      Sticky Bun    1800  November
# 9   2016-11-08    Tuesday         Brownie    1900  November
# 10  2016-11-08    Tuesday      Bread Roll    1900  November
# 11  2016-11-09  Wednesday   Walnut Muffin    2800  November
# 12  2016-11-09  Wednesday          Samosa    1700  November
# 13  2016-11-10   Thursday        Cinnabun    1900  November
# 14  2016-11-10   Thursday    Salt Biscuit    1900  November
# 15  2016-11-13     Sunday   Orange Muffin    2300  November
# ...

# %%
from dateutil.parser import parse
start_date=parse("2016-11-02")

# %%
snacks['Date_Diff']=snacks['Date'].apply(lambda x: (x-start_date).days)

# %%
snacks['Percentage Consumed']=87

# %%
#snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,"%d/%m/%Y"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-310-3a82a58582c6> in <module>()
# ----> 1 snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,"%d/%m/%Y"))
#
# C:\Anaconda2\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:62658)()
#
# <ipython-input-310-3a82a58582c6> in <lambda>(x)
# ----> 1 snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,"%d/%m/%Y"))
#
# TypeError: strptime() argument 1 must be string, not Timestamp

# %%
snacks['Date_Diff']=snacks['Date_Diff'].apply(lambda x:x/40.0)
snacks
# Out:
#           Date        Day            Item Ordered     Month  \
# 1   2016-11-02  Wednesday   Walnut Muffin    2900  November
# 2   2016-11-02  Wednesday          Samosa    1800  November
# 3   2016-11-03   Thursday         Brownie    1800  November
# 4   2016-11-03   Thursday    Salt Biscuit    1800  November
# 5   2016-11-06     Sunday   Orange Muffin    1800  November
# 6   2016-11-06     Sunday     Irish Scone    1800  November
# 7   2016-11-07     Monday   Spiced Peanut    1800  November
# 8   2016-11-07     Monday      Sticky Bun    1800  November
# 9   2016-11-08    Tuesday         Brownie    1900  November
# 10  2016-11-08    Tuesday      Bread Roll    1900  November
# 11  2016-11-09  Wednesday   Walnut Muffin    2800  November
# 12  2016-11-09  Wednesday          Samosa    1700  November
# 13  2016-11-10   Thursday        Cinnabun    1900  November
# 14  2016-11-10   Thursday    Salt Biscuit    1900  November
# 15  2016-11-13     Sunday   Orange Muffin    2300  November
# ...

# %%
snacks
# Out:
#           Date        Day            Item Ordered     Month  \
# 1   2016-11-02  Wednesday   Walnut Muffin    2900  November
# 2   2016-11-02  Wednesday          Samosa    1800  November
# 3   2016-11-03   Thursday         Brownie    1800  November
# 4   2016-11-03   Thursday    Salt Biscuit    1800  November
# 5   2016-11-06     Sunday   Orange Muffin    1800  November
# 6   2016-11-06     Sunday     Irish Scone    1800  November
# 7   2016-11-07     Monday   Spiced Peanut    1800  November
# 8   2016-11-07     Monday      Sticky Bun    1800  November
# 9   2016-11-08    Tuesday         Brownie    1900  November
# 10  2016-11-08    Tuesday      Bread Roll    1900  November
# 11  2016-11-09  Wednesday   Walnut Muffin    2800  November
# 12  2016-11-09  Wednesday          Samosa    1700  November
# 13  2016-11-10   Thursday        Cinnabun    1900  November
# 14  2016-11-10   Thursday    Salt Biscuit    1900  November
# 15  2016-11-13     Sunday   Orange Muffin    2300  November
# ...

# %%
snacks['Percentage Consumed']=snacks['Percentage Consumed']+snacks['Date_Diff']
snacks
# Out:
#           Date        Day            Item Ordered     Month  \
# 1   2016-11-02  Wednesday   Walnut Muffin    2900  November
# 2   2016-11-02  Wednesday          Samosa    1800  November
# 3   2016-11-03   Thursday         Brownie    1800  November
# 4   2016-11-03   Thursday    Salt Biscuit    1800  November
# 5   2016-11-06     Sunday   Orange Muffin    1800  November
# 6   2016-11-06     Sunday     Irish Scone    1800  November
# 7   2016-11-07     Monday   Spiced Peanut    1800  November
# 8   2016-11-07     Monday      Sticky Bun    1800  November
# 9   2016-11-08    Tuesday         Brownie    1900  November
# 10  2016-11-08    Tuesday      Bread Roll    1900  November
# 11  2016-11-09  Wednesday   Walnut Muffin    2800  November
# 12  2016-11-09  Wednesday          Samosa    1700  November
# 13  2016-11-10   Thursday        Cinnabun    1900  November
# 14  2016-11-10   Thursday    Salt Biscuit    1900  November
# 15  2016-11-13     Sunday   Orange Muffin    2300  November
# ...

# %%
import random
import decimal
r=1
count3=0
while r<len(snacks):
    print("r is %d"%r)
    val=snacks.ix[r]['Percentage Consumed']
    rg=random.randint(0,3)
    if rg==3:
        count3+=1
        if count3%3==1:
            rg-=1
        elif count3%3==2:
            rg-=2
    add=0
    print("rg is %d"%rg)
    if rg!=0:
        rg*=1000
        rg2=-1*rg
        add=float(decimal.Decimal(random.randrange(rg2,rg))/1000)
    snacks.ix[r,'Percentage Consumed']=val+add
    inc=random.randint(0,5)
    r+=inc
# Out:
# r is 1
# rg is 1
# r is 3
# rg is 2
# r is 6
# rg is 1
# r is 11
# rg is 1
# r is 16
# rg is 3
# r is 18
# rg is 2
# r is 23
# rg is 1
# r is 25
# rg is 1
# r is 26
# rg is 3
# r is 28
# rg is 1
# r is 33
# rg is 2
# r is 34
# rg is 0
# r is 38
# rg is 1
# r is 38
# rg is 0
# r is 42
# rg is 3
# r is 44
# rg is 2
# r is 45
# rg is 0
# r is 50
# rg is 2
# r is 55
# rg is 1
# r is 57
# rg is 2
# r is 61
# rg is 1
# r is 64
# rg is 1
# r is 65
# rg is 0
# r is 68
# rg is 1
# r is 71
# rg is 2
# r is 71
# rg is 1
# r is 76
# rg is 3
# r is 76
# rg is 0
# r is 80
# rg is 2
# r is 83
# rg is 2
# r is 84
# rg is 0
# r is 87
# rg is 0
# r is 88
# rg is 2
# r is 93
# rg is 2
# r is 96
# rg is 2
# r is 99
# rg is 1
# r is 99
# rg is 1
# r is 102
# rg is 0
# r is 104
# rg is 0
# r is 105
# rg is 0
# r is 109
# rg is 0
# r is 111
# rg is 2
# r is 111
# rg is 0
# r is 113
# rg is 3
# r is 116
# rg is 2
# r is 116
# rg is 2
# r is 120
# rg is 2
# r is 123
# rg is 1
# r is 125
# rg is 1
# r is 128
# ...

# %%
snacks
# Out:
#           Date        Day            Item Ordered     Month  \
# 1   2016-11-02  Wednesday   Walnut Muffin    2900  November
# 2   2016-11-02  Wednesday          Samosa    1800  November
# 3   2016-11-03   Thursday         Brownie    1800  November
# 4   2016-11-03   Thursday    Salt Biscuit    1800  November
# 5   2016-11-06     Sunday   Orange Muffin    1800  November
# 6   2016-11-06     Sunday     Irish Scone    1800  November
# 7   2016-11-07     Monday   Spiced Peanut    1800  November
# 8   2016-11-07     Monday      Sticky Bun    1800  November
# 9   2016-11-08    Tuesday         Brownie    1900  November
# 10  2016-11-08    Tuesday      Bread Roll    1900  November
# 11  2016-11-09  Wednesday   Walnut Muffin    2800  November
# 12  2016-11-09  Wednesday          Samosa    1700  November
# 13  2016-11-10   Thursday        Cinnabun    1900  November
# 14  2016-11-10   Thursday    Salt Biscuit    1900  November
# 15  2016-11-13     Sunday   Orange Muffin    2300  November
# ...

# %%
snacks.to_csv('../random_data_1.csv',index=False)

# %%
snacks=pd.read_csv('../random_data_1.csv')
snacks
# Out:
#            Date        Day            Item  Ordered     Month  \
# 0    2016-11-02  Wednesday   Walnut Muffin     2900  November
# 1    2016-11-02  Wednesday          Samosa     1800  November
# 2    2016-11-03   Thursday         Brownie     1800  November
# 3    2016-11-03   Thursday    Salt Biscuit     1800  November
# 4    2016-11-06     Sunday   Orange Muffin     1800  November
# 5    2016-11-06     Sunday     Irish Scone     1800  November
# 6    2016-11-07     Monday   Spiced Peanut     1800  November
# 7    2016-11-07     Monday      Sticky Bun     1800  November
# 8    2016-11-08    Tuesday         Brownie     1900  November
# 9    2016-11-08    Tuesday      Bread Roll     1900  November
# 10   2016-11-09  Wednesday   Walnut Muffin     2800  November
# 11   2016-11-09  Wednesday          Samosa     1700  November
# 12   2016-11-10   Thursday        Cinnabun     1900  November
# 13   2016-11-10   Thursday    Salt Biscuit     1900  November
# ...

# %%
snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,"%Y-%m-%d"))
snacks['Date']=snacks['Date'].apply(lambda x:x+datetime.timedelta(days=1))
snacks['Day']=snacks['Date'].apply(lambda x:x.weekday())
snacks['Day']=snacks['Day'].apply(lambda x:calendar.day_name[x])
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday   Spiced Peanut     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
l=list(snacks['Day'])
if 'Saturday' in l:
    print('n000')

# %%
for r in range(0,316):
    date=snacks.ix[r]['Date']
    day=str(date).split(' ')[0]
    day=str(day).split('-')[2]
    if int(day)<=7:
        snacks.ix[r,'Week']=1
    elif int(day)<=14:
        snacks.ix[r,'Week']=2
    elif int(day)<=21:
        snacks.ix[r,'Week']=3
    elif int(day)<=28:
        snacks.ix[r,'Week']=4
    else:
        snacks.ix[r,'Week']=5

# %%
for r in range(0,316):
    if snacks.ix[r]['Week']==1.0:
        i=random.randint(0,1500)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Week']==2.0:
        i=random.randint(0,1000)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Week']==3.0:
        i=random.randint(0,700)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Week']==4.0:
        i=random.randint(0,400)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday   Spiced Peanut     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
for r in range(0,316):
    if snacks.ix[r]['Day']=='Monday':
        i=random.randint(-1600,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Day']=='Tuesday':
        i=random.randint(0,1400)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Day']=='Wednesday':
        i=random.randint(-1000,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Day']=='Thursday':
        i=random.randint(0,1000)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Day']=='Friday':
        i=random.randint(-2000,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
snacks
# Out:
#            Date        Day            Item  Ordered     Month  \
# 0    2016-11-02  Wednesday   Walnut Muffin     2900  November
# 1    2016-11-02  Wednesday          Samosa     1800  November
# 2    2016-11-03   Thursday         Brownie     1800  November
# 3    2016-11-03   Thursday    Salt Biscuit     1800  November
# 4    2016-11-06     Sunday   Orange Muffin     1800  November
# 5    2016-11-06     Sunday     Irish Scone     1800  November
# 6    2016-11-07     Monday   Spiced Peanut     1800  November
# 7    2016-11-07     Monday      Sticky Bun     1800  November
# 8    2016-11-08    Tuesday         Brownie     1900  November
# 9    2016-11-08    Tuesday      Bread Roll     1900  November
# 10   2016-11-09  Wednesday   Walnut Muffin     2800  November
# 11   2016-11-09  Wednesday          Samosa     1700  November
# 12   2016-11-10   Thursday        Cinnabun     1900  November
# 13   2016-11-10   Thursday    Salt Biscuit     1900  November
# ...

# %%
print(item_list)
# Out:
# ['Rusk', 'Bagel', 'Samosa', 'Brownie', 'Biscuit', 'Crumpet', 'Popover', 'Kolache', 'Cinnabun', 'Egg Puff', 'Biscotti', 'Koduballe', 'Plum Cake', 'Croissant', 'Casserole', 'Cornbread', 'Cream Bun', 'Apple Pie', 'Apple Bar', 'Energy Bar', 'Date Bread', 'Bread Roll', 'Sticky Bun', 'Lemon Cake', 'Masala Bun', 'Pita Bread', 'Apple Tart', 'Apple Cake', 'Granola Bar', 'Irish Scone', 'Apple Bread', 'Lemon Scone', 'Baked Donut', 'Potato Chip', 'Marble Cake', 'Bran Muffin', 'Irish Bread', 'Nutty Scone', 'Cherry Tart', 'Gingerbread', 'Easter Cake', 'Coffee Cake', 'Salt Biscuit', 'Cherry Scone', 'Apple Pastry', 'Sugar Cookie', 'Key Lime Pie', 'Cream Muffin', 'Peach Muffin', 'Pecan Muffin', 'Caramel Tart', 'Bread Pakoda', 'French Bread', 'Badam Cookie', 'Peach Muffin', 'Maple Muffin', 'Herb Cracker', 'Banana Muffin', 'Cinnamon Cake', 'Carrot Muffin', 'Granola Scone', 'Coconut Bread', 'Spiced Peanut', 'Walnut Muffin', 'Orange Muffin', 'Cinnamon Roll', 'Oatmeal Scone', 'Vegetable Puff', 'Boondi Mix
# ...

# %%
for r in range(0,len(snacks)):
    if snacks.ix[r]['Item'] in item_list[0:5]:
        i=random.randint(0,1000)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Item'] in item_list[5:30]:
        i=random.randint(-700,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Item'] in item_list[30:50]:
        i=random.randint(0,800)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Item'] in item_list[50:70]:
        i=random.randint(-800,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday   Spiced Peanut     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
for r in range(1,len(snacks)):
    if snacks.ix[r]['Item']=='Herb Cracker':
        i=random.randint(-1000,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Item']=='Gingerbread':
        i=random.randint(-700,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Item']=='Coconut Muffin':
        i=random.randint(-300,0)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
    elif snacks.ix[r]['Item']=='Spiced Peanut':
        i=random.randint(0,700)/1000.0
        snacks.ix[r, 'Percentage Consumed']=snacks.ix[r]['Percentage Consumed']+i
snacks
# Out:
#            Date        Day            Item  Ordered     Month  \
# 0    2016-11-02  Wednesday   Walnut Muffin     2900  November
# 1    2016-11-02  Wednesday          Samosa     1800  November
# 2    2016-11-03   Thursday         Brownie     1800  November
# 3    2016-11-03   Thursday    Salt Biscuit     1800  November
# 4    2016-11-06     Sunday   Orange Muffin     1800  November
# 5    2016-11-06     Sunday     Irish Scone     1800  November
# 6    2016-11-07     Monday   Spiced Peanut     1800  November
# 7    2016-11-07     Monday      Sticky Bun     1800  November
# 8    2016-11-08    Tuesday         Brownie     1900  November
# 9    2016-11-08    Tuesday      Bread Roll     1900  November
# 10   2016-11-09  Wednesday   Walnut Muffin     2800  November
# 11   2016-11-09  Wednesday          Samosa     1700  November
# 12   2016-11-10   Thursday        Cinnabun     1900  November
# 13   2016-11-10   Thursday    Salt Biscuit     1900  November
# ...

# %%
for r in range(1,len(snacks)):
    if snacks.ix[r]['Item']=='Spiced Peanut':
        snacks.ix[r,'Item']='Spiced Peanuts'

# %%
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
snacks['Footfall']=700

# %%
for r in range(0,316):
    if snacks.ix[r]['Day']=='Monday':
        i=random.randint(-5000,0)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
    elif snacks.ix[r]['Day']=='Tuesday':
        i=random.randint(0,3000)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
    elif snacks.ix[r]['Day']=='Wednesday':
        i=random.randint(-4000,0)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
    elif snacks.ix[r]['Day']=='Thursday':
        i=random.randint(0,1000)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
    elif snacks.ix[r]['Day']=='Friday':
        i=random.randint(-7000,0)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
snacks.to_csv('../random_data_2.csv')

# %%
snacks=pd.read_csv('../random_data_2.csv')
snacks.pop('Unnamed: 0')
snacks
# Out:
#            Date        Day            Item  Ordered     Month  \
# 0    2016-11-03   Thursday   Walnut Muffin     2900  November
# 1    2016-11-03   Thursday          Samosa     1800  November
# 2    2016-11-04     Friday         Brownie     1800  November
# 3    2016-11-04     Friday    Salt Biscuit     1800  November
# 4    2016-11-07     Monday   Orange Muffin     1800  November
# 5    2016-11-07     Monday     Irish Scone     1800  November
# 6    2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7    2016-11-08    Tuesday      Sticky Bun     1800  November
# 8    2016-11-09  Wednesday         Brownie     1900  November
# 9    2016-11-09  Wednesday      Bread Roll     1900  November
# 10   2016-11-10   Thursday   Walnut Muffin     2800  November
# 11   2016-11-10   Thursday          Samosa     1700  November
# 12   2016-11-11     Friday        Cinnabun     1900  November
# 13   2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,"%Y-%m-%d"))
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
snacks['Month']=snacks['Date'].apply(lambda x:calendar.month_name[x.month])
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
for r in range(0,316):
    if snacks.ix[r]['Month']=='December':
        i=random.randint(-20000,-10000)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
    elif snacks.ix[r]['Day']=='May':
        i=random.randint(-21000,-11000)/100.0
        snacks.ix[r, 'Footfall']=snacks.ix[r]['Footfall']+i
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
for r in range(0,316):
    print(str(snacks.ix[r]['Date'].date()))
    if str(snacks.ix[r]['Date'].date())=='2017-01-26':
        snacks=snacks.drop(r)
        print('ello')
snacks
# Out:
# 2016-11-03
# 2016-11-03
# 2016-11-04
# 2016-11-04
# 2016-11-07
# 2016-11-07
# 2016-11-08
# 2016-11-08
# 2016-11-09
# 2016-11-09
# 2016-11-10
# 2016-11-10
# 2016-11-11
# 2016-11-11
# 2016-11-14
# 2016-11-14
# 2016-11-15
# 2016-11-15
# 2016-11-16
# 2016-11-16
# 2016-11-17
# 2016-11-17
# 2016-11-18
# 2016-11-18
# 2016-11-21
# 2016-11-21
# 2016-11-22
# 2016-11-22
# 2016-11-23
# 2016-11-23
# 2016-11-24
# 2016-11-24
# 2016-11-25
# 2016-11-25
# 2016-11-28
# 2016-11-28
# 2016-11-29
# 2016-11-29
# 2016-11-30
# 2016-11-30
# 2016-12-01
# 2016-12-01
# 2016-12-02
# 2016-12-02
# 2016-12-05
# 2016-12-05
# 2016-12-06
# 2016-12-06
# 2016-12-07
# 2016-12-07
# 2016-12-08
# 2016-12-08
# 2016-12-09
# 2016-12-09
# 2016-12-12
# 2016-12-12
# 2016-12-13
# 2016-12-13
# 2016-12-14
# 2016-12-14
# 2016-12-15
# 2016-12-15
# 2016-12-16
# 2016-12-16
# 2016-12-19
# 2016-12-19
# 2016-12-20
# 2016-12-20
# 2016-12-21
# 2016-12-21
# 2016-12-22
# 2016-12-22
# 2016-12-23
# 2016-12-23
# 2016-12-27
# 2016-12-27
# ...

# %%
snacks.to_csv('../random_data_3_useless.csv',index=False)

# %%
snacks=pd.read_csv('../random_data_3_useless.csv')
snacks
# Out:
#            Date        Day            Item  Ordered     Month  \
# 0    2016-11-03   Thursday   Walnut Muffin     2900  November
# 1    2016-11-03   Thursday          Samosa     1800  November
# 2    2016-11-04     Friday         Brownie     1800  November
# 3    2016-11-04     Friday    Salt Biscuit     1800  November
# 4    2016-11-07     Monday   Orange Muffin     1800  November
# 5    2016-11-07     Monday     Irish Scone     1800  November
# 6    2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7    2016-11-08    Tuesday      Sticky Bun     1800  November
# 8    2016-11-09  Wednesday         Brownie     1900  November
# 9    2016-11-09  Wednesday      Bread Roll     1900  November
# 10   2016-11-10   Thursday   Walnut Muffin     2800  November
# 11   2016-11-10   Thursday          Samosa     1700  November
# 12   2016-11-11     Friday        Cinnabun     1900  November
# 13   2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
snacks['Date']=snacks['Date'].apply(lambda x:datetime.datetime.strptime(x,"%Y-%m-%d"))

# %%
for r in range(0,312):
    x=str(snacks.ix[r]['Date'].date())
    if x=='2016-12-25' or x=='2016-11-01' or x=='2017-01-14' or x=='2017-05-01' or x=='2017-01-01':
        snacks=snacks.drop(r)
snacks
# Out:
#           Date        Day            Item  Ordered     Month  \
# 0   2016-11-03   Thursday   Walnut Muffin     2900  November
# 1   2016-11-03   Thursday          Samosa     1800  November
# 2   2016-11-04     Friday         Brownie     1800  November
# 3   2016-11-04     Friday    Salt Biscuit     1800  November
# 4   2016-11-07     Monday   Orange Muffin     1800  November
# 5   2016-11-07     Monday     Irish Scone     1800  November
# 6   2016-11-08    Tuesday  Spiced Peanuts     1800  November
# 7   2016-11-08    Tuesday      Sticky Bun     1800  November
# 8   2016-11-09  Wednesday         Brownie     1900  November
# 9   2016-11-09  Wednesday      Bread Roll     1900  November
# 10  2016-11-10   Thursday   Walnut Muffin     2800  November
# 11  2016-11-10   Thursday          Samosa     1700  November
# 12  2016-11-11     Friday        Cinnabun     1900  November
# 13  2016-11-11     Friday    Salt Biscuit     1900  November
# ...

# %%
snacks.to_csv('../random_final.csv',index=False)
